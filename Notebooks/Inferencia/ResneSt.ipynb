# %% [markdown]
# # 1. Instalamos Detectron2
# Nos guiaremos del tutorial ofrecido por la fuente oficial de [Detectron2](https://colab.research.google.com/drive/16jcaJoc6bCFAQ96jDe2HwtXj7BMD_-m5#scrollTo=vM54r6jlKTII)

# %%
# instalación de dependencias
# !pip install -U torch==1.5 torchvision==0.6 -f https://download.pytorch.org/whl/cu101/torch_stable.html 
# !pip install cython pyyaml==5.1
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'

# %%
# instalamos resnest
# !python -m pip install 'git+https://github.com/zhanghang1989/detectron2-ResNeSt.git'

# %% [markdown]
# # 2. Detección con ResNeSt
# Procedemos a replicar el funcionamiento de ResNeSt para Faster-RCNN. Para ello, descargaremos los recursos necesarios y posteriormente aplicaremos las funciones diseñadas por los autores para la detección sobre una imagen.

# %%
# descargamos el modelo 
# !wget https://s3.us-west-1.wasabisys.com/resnest/detectron/faster_rcnn_ResNeSt_50_FPN_syncbn_range-scale_1x-ad123c0b.pth -O model.pth

# %%
# descargamos el repositorio
# !wget https://github.com/zhanghang1989/detectron2-ResNeSt/archive/resnest.zip
# !unzip resnest.zip

# %%
# Ejecutamos la predicción
# !wget http://images.cocodataset.org/val2017/000000439715.jpg -O input.jpg
# !python /content/detectron2-ResNeSt-resnest/demo/demo.py --config-file /content/detectron2-ResNeSt-resnest/configs/COCO-Detection/faster_rcnn_ResNeSt_50_FPN_syncbn_range-scale_1x.yaml --input input.jpg --output out.jpg --opts MODEL.WEIGHTS /content/model.pth MODEL.DEVICE cpu

# %%
from IPython.display import Image
im = Image(filename='/content/out.jpg')
display(im)
